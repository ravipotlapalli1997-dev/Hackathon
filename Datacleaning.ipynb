# %%
# !pip install pandas

# %%
#Importing all the Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore", UserWarning)

# %%
#Reading the file 
df= pd.read_csv("C:/Users/vukch/Downloads/Flatten_Covid19_Dataset-20251217T033833Z-1-001/Flatten_Covid19_Dataset/schema_1_ontario_final.csv")

# %%
df=df= pd.read_csv("C:/Users/vukch/Downloads/Flatten_Covid19_Dataset-20251217T033833Z-1-001/Flatten_Covid19_Dataset/schema_1_ontario_final.csv")
# Out:
#     week  fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0     13  L4C        n          n              y                   n     n
# 1     13  P1H        y          y              y                   n     n
# 2     14  N2J        n          y              y                   n     n
# 3     13  N1G        n          n              y                   n     n
# 4     13  M1P        n          y              n                   n     n
# ..   ...  ...      ...        ...            ...                 ...   ...
# 95    15  L6M        n          n              y                   n     n
# 96    14  L6M        n          n              n                   n     n
# 97    13  L9A        n          n              y                   n     n
# 98    13  P0M        n          y              y                   n     n
# 99    13  L0R        n          n              y                   n     n
#
# ...

# %%
for index, row in dataset.head(100).iterrows():
    print(row)
# Out:
# week                       13
# fsa                       L4C
# probable                    n
# vulnerable                  n
# is_most_recent              y
# fever_chills_shakes         n
# cough                       n
# shortness_of_breath         n
# over_60                     n
# any_medical_conditions      n
# travel_outside_canada       n
# contact_with_illness        n
# Name: 0, dtype: object
# week                       13
# fsa                       P1H
# probable                    y
# vulnerable                  y
# is_most_recent              y
# fever_chills_shakes         n
# cough                       n
# shortness_of_breath         n
# over_60                     y
# any_medical_conditions      y
# travel_outside_canada       n
# contact_with_illness        y
# Name: 1, dtype: object
# week                       14
# fsa                       N2J
# probable                    n
# vulnerable                  y
# is_most_recent              y
# ...

# %%
dataset.head(100).to_csv("preview.csv", index=False)

# %%
df1 = pd.read_csv("C:/Users/vukch/Downloads/Flatten_Covid19_Dataset-20251217T033833Z-1-001/Flatten_Covid19_Dataset/schema_1_ontario_final.csv", nrows=100)
df2 = pd.read_csv("C:/Users/vukch/Downloads/Flatten_Covid19_Dataset-20251217T033833Z-1-001/Flatten_Covid19_Dataset/schema_2_ontario_final.csv",nrows=100)
df3 = pd.read_csv("C:/Users/vukch/Downloads/Flatten_Covid19_Dataset-20251217T033833Z-1-001/Flatten_Covid19_Dataset/schema_3_ontario_final.csv",nrows=100)
for df in [df1, df2, df3]:
    with pd.option_context('display.max_rows',None):
        print(df1)
        print(df2)
        print(df3)
# Out:
# ...
#     week  fsa probable vulnerable is_most_recent fever_chills_shakes cough  \
# 0     15  M1P        n          n              y                   n     n
# 1     16  N2P        n          y              y                   n     n
# 2     16  N2P        n          y              n                   n     n
# 3     16  M4P        n          n              y                   n     n
# 4     16  L4N        n          n              y                   n     n
# 5     15  M4S        n          n              y                   n     n
# 6     16  L0L        n          n              y                   n     n
# 7     15  L6Y        n          y              y                   n     n
# 8     15  K2K        n          n              y                   n     n
# 9     16  L6M        n          n              y                   n     n
# 10    15  N2P        n          n              y                   n     n
# ...

# %%
for df in [df1, df2, df3]:
    df.columns = df.columns.str.lower().str.strip()
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263639 entries, 0 to 263638
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   week                    263639 non-null  int64
#  1   fsa                     263639 non-null  object
#  2   probable                263639 non-null  object
#  3   vulnerable              263639 non-null  object
#  4   is_most_recent          263639 non-null  object
#  5   fever_chills_shakes     263639 non-null  object
#  6   cough                   263639 non-null  object
#  7   shortness_of_breath     263639 non-null  object
#  8   over_60                 263639 non-null  object
#  9   any_medical_conditions  263639 non-null  object
#  10  travel_outside_canada   263639 non-null  object
#  11  contact_with_illness    263639 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 24.1+ MB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
df1.head(10)
df2.head(10)
df3.head(10)
yn_map = {'y': 1, 'n': 0}
binary_cols = [
    'probable','vulnerable','is_most_recent',
    'fever_chills_shakes','cough','shortness_of_breath',
    'over_60','any_medical_conditions',
    'travel_outside_canada','contact_with_illness',
    'self_isolating','tobacco_usage'
]
for df in [df1, df2, df3]:
    for col in binary_cols:
        if col in df.columns:
            df[col] = df[col].map(yn_map)
